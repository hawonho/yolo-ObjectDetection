# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\user\anaconda3\envs\yolo_project_env01\lib\site-packages (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\envs\yolo_project_env01\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\envs\yolo_project_env01\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\envs\yolo_project_env01\lib\site-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\anaconda3\envs\yolo_project_env01\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\user\anaconda3\envs\yolo_project_env01\lib\site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\envs\yolo_project_env01\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\user\anaconda3\envs\yolo_project_env01\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\anaconda3\envs\yolo_project_env01\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\envs\yolo_project_env01\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\envs\yolo_project_env01\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\user\anaconda3\envs\yolo_project_env01\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\user\anaconda3\envs\yolo_project_env01\lib\site-packages (from opencv-python) (1.23.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install selectivesearch
# Out:
# Requirement already satisfied: selectivesearch in c:\users\user\anaconda3\envs\yolo_project_env01\lib\site-packages (0.4)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\envs\yolo_project_env01\lib\site-packages (from selectivesearch) (1.23.5)
# Requirement already satisfied: scikit-image in c:\users\user\anaconda3\envs\yolo_project_env01\lib\site-packages (from selectivesearch) (0.24.0)
# Requirement already satisfied: scipy>=1.9 in c:\users\user\anaconda3\envs\yolo_project_env01\lib\site-packages (from scikit-image->selectivesearch) (1.14.0)
# Requirement already satisfied: networkx>=2.8 in c:\users\user\anaconda3\envs\yolo_project_env01\lib\site-packages (from scikit-image->selectivesearch) (3.3)
# Requirement already satisfied: pillow>=9.1 in c:\users\user\anaconda3\envs\yolo_project_env01\lib\site-packages (from scikit-image->selectivesearch) (10.4.0)
# Requirement already satisfied: imageio>=2.33 in c:\users\user\anaconda3\envs\yolo_project_env01\lib\site-packages (from scikit-image->selectivesearch) (2.34.2)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\user\anaconda3\envs\yolo_project_env01\lib\site-packages (from scikit-image->selectivesearch) (2024.6.18)
# Requirement already satisfied: packaging>=21 in c:\users\user\anaconda3\envs\yolo_project_env01\lib\site-packages (from scikit-image->selectivesearch) (24.1)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\user\anaconda3\envs\yolo_project_env01\lib\site-packages (from scikit-image->selectivesearch) (0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import os
import cv2

# %%
img = cv2.imread("audrey01.jpg")
plt.imshow(img)

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
import selectivesearch

# %%
img_lbl, regions = selectivesearch.selective_search(img_rgb, scale=100, min_size=2000)
# Out:
# C:\Users\User\anaconda3\envs\yolo_project_env01\lib\site-packages\skimage\feature\texture.py:360: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(

# %%
img_lbl
# Out:
# array([[[ 85.,  85.,  85.,   0.],
#         [ 84.,  84.,  84.,   0.],
#         [ 75.,  75.,  75.,   0.],
#         ...,
#         [212., 212., 212.,   2.],
#         [215., 215., 215.,   2.],
#         [218., 218., 218.,   2.]],
#
#        [[ 83.,  83.,  83.,   0.],
#         [ 82.,  82.,  82.,   0.],
#         [ 73.,  73.,  73.,   0.],
#         ...,
#         [216., 216., 216.,   2.],
#         [220., 220., 220.,   2.],
#         [223., 223., 223.,   2.]],
#
#        [[ 80.,  80.,  80.,   0.],
#         [ 79.,  79.,  79.,   0.],
#         [ 71.,  71.,  71.,   0.],
#         ...,
#         [219., 219., 219.,   2.],
#         [225., 225., 225.,   2.],
#         [228., 228., 228.,   2.]],
#
#        ...,
#
#        [[214., 214., 214.,  19.],
#         [211., 211., 211.,  19.],
#         [213., 213., 213.,  19.],
#         ...,
#         [104., 104., 104.,  20.],
#         [112., 112., 112.,  20.],
#         [115., 115., 115.,  20.]],
#
#        [[221., 221., 221.,  19.],
#         [214., 214., 214.,  19.],
#         [215., 215., 215.,  19.],
#         ...,
#         [104., 104., 104.,  20.],
#         [105., 105., 105.,  20.],
#         [111., 111., 111.,  20.]],
#
#        [[237., 237., 237.,  19.],
#         [230., 230., 230.,  19.],
#         [230., 230., 230.,  19.],
#         ...,
#         [ 97.,  97.,  97.,  20.],
#         [ 97.,  97.,  97.,  20.],
#         [107., 107., 107.,  20.]]])

# %%
img_lbl.shape
# Out:
# (450, 375, 4)

# %%
plt.imshow(img_lbl[ : , : , 0:3 ].astype(int ) )

# %%
plt.imshow(img_lbl[ : , : , 3 ].astype(int ) )

# %%
regions
# Out:
# [{'rect': (0, 0, 107, 167), 'size': 11166, 'labels': [0.0]},
#  {'rect': (15, 0, 129, 110), 'size': 8771, 'labels': [1.0]},
#  {'rect': (121, 0, 253, 133), 'size': 17442, 'labels': [2.0]},
#  {'rect': (134, 17, 73, 62), 'size': 2713, 'labels': [3.0]},
#  {'rect': (166, 23, 87, 176), 'size': 8639, 'labels': [4.0]},
#  {'rect': (136, 53, 88, 121), 'size': 4617, 'labels': [5.0]},
#  {'rect': (232, 79, 117, 147), 'size': 7701, 'labels': [6.0]},
#  {'rect': (50, 91, 133, 123), 'size': 7042, 'labels': [7.0]},
#  {'rect': (305, 97, 69, 283), 'size': 11373, 'labels': [8.0]},
#  {'rect': (0, 161, 70, 46), 'size': 2363, 'labels': [9.0]},
#  {'rect': (72, 171, 252, 222), 'size': 34467, 'labels': [10.0]},
#  {'rect': (0, 181, 118, 85), 'size': 5270, 'labels': [11.0]},
#  {'rect': (106, 210, 89, 101), 'size': 2868, 'labels': [12.0]},
#  {'rect': (302, 228, 66, 96), 'size': 2531, 'labels': [13.0]},
#  {'rect': (0, 253, 92, 134), 'size': 7207, 'labels': [14.0]},
#  {'rect': (153, 270, 173, 179), 'size': 10360, 'labels': [15.0]},
#  {'rect': (0, 305, 47, 139), 'size': 4994, 'labels': [16.0]},
#  {'rect': (104, 312, 80, 71), 'size': 3595, 'labels': [17.0]},
#  {'rect': (84, 360, 91, 67), 'size': 2762, 'labels': [18.0]},
#  {'rect': (0, 362, 171, 87), 'size': 7705, 'labels': [19.0]},
#  {'rect': (297, 364, 77, 85), 'size': 5164, 'labels': [20.0]},
#  {'rect': (0, 91, 183, 175), 'size': 12312, 'labels': [7.0, 11.0]},
#  {'rect': (136, 23, 117, 176), 'size': 13256, 'labels': [4.0, 5.0]},
#  {'rect': (72, 171, 254, 278), 'size': 44827, 'labels': [10.0, 15.0]},
#  {'rect': (134, 17, 119, 182), 'size': 15969, 'labels': [4.0, 5.0, 3.0]},
#  {'rect': (302, 97, 72, 283), 'size': 13904, 'labels': [8.0, 13.0]},
#  {'rect': (121, 0, 253, 226), 'size': 25143, 'labels': [2.0, 6.0]},
#  {'rect': (0, 91, 183, 175), 'size': 14675, 'labels': [7.0, 11.0, 9.0]},
#  {'rect': (0, 0, 144, 167), 'size': 19937, 'labels': [0.0, 1.0]},
#  {'rect': (0, 0, 253, 199),
#   'size': 35906,
#   'labels': [0.0, 1.0, 4.0, 5.0, 3.0]},
#  {'rect': (0, 253, 92, 191), 'size': 12201, 'labels': [14.0, 16.0]},
#  {'rect': (0, 91, 183, 353),
#   'size': 26876,
#   'labels': [14.0, 16.0, 7.0, 11.0, 9.0]},
#  {'rect': (0, 171, 326, 278), 'size': 52532, 'labels': [10.0, 15.0, 19.0]},
#  {'rect': (0, 97, 374, 352),
#   'size': 66436,
#   'labels': [10.0, 15.0, 19.0, 8.0, 13.0]},
#  {'rect': (84, 312, 100, 115), 'size': 6357, 'labels': [17.0, 18.0]},
#  {'rect': (0, 91, 184, 353),
#   'size': 33233,
#   'labels': [17.0, 18.0, 14.0, 16.0, 7.0, 11.0, 9.0]},
#  {'rect': (0, 91, 195, 353),
#   'size': 36101,
#   'labels': [17.0, 18.0, 14.0, 16.0, 7.0, 11.0, 9.0, 12.0]},
#  {'rect': (0, 0, 374, 444),
#   'size': 61244,
#   'labels': [17.0, 18.0, 14.0, 16.0, 7.0, 11.0, 9.0, 12.0, 2.0, 6.0]},
#  {'rect': (0, 0, 374, 449),
#   'size': 127680,
#   'labels': [17.0,
#    18.0,
#    14.0,
#    16.0,
#    7.0,
#    11.0,
#    9.0,
#    12.0,
#    2.0,
#    6.0,
#    10.0,
#    15.0,
#    19.0,
#    8.0,
#    13.0]},
#  {'rect': (0, 0, 374, 449),
#   'size': 132844,
#   'labels': [17.0,
#    18.0,
#    14.0,
#    16.0,
#    7.0,
#    11.0,
#    9.0,
#    12.0,
#    2.0,
#    6.0,
#    10.0,
#    15.0,
#    19.0,
#    8.0,
#    13.0,
#    20.0]},
#  {'rect': (0, 0, 374, 449),
#   'size': 168750,
#   'labels': [17.0,
#    18.0,
#    14.0,
#    16.0,
#    7.0,
#    11.0,
#    9.0,
#    12.0,
#    2.0,
#    6.0,
#    10.0,
#    15.0,
#    19.0,
#    8.0,
#    13.0,
#    20.0,
#    0.0,
#    1.0,
#    4.0,
#    5.0,
#    3.0]}]

# %%
[ "c="+str(cand) for cand in regions ]
# Out:
# ["c={'rect': (0, 0, 107, 167), 'size': 11166, 'labels': [0.0]}",
#  "c={'rect': (15, 0, 129, 110), 'size': 8771, 'labels': [1.0]}",
#  "c={'rect': (121, 0, 253, 133), 'size': 17442, 'labels': [2.0]}",
#  "c={'rect': (134, 17, 73, 62), 'size': 2713, 'labels': [3.0]}",
#  "c={'rect': (166, 23, 87, 176), 'size': 8639, 'labels': [4.0]}",
#  "c={'rect': (136, 53, 88, 121), 'size': 4617, 'labels': [5.0]}",
#  "c={'rect': (232, 79, 117, 147), 'size': 7701, 'labels': [6.0]}",
#  "c={'rect': (50, 91, 133, 123), 'size': 7042, 'labels': [7.0]}",
#  "c={'rect': (305, 97, 69, 283), 'size': 11373, 'labels': [8.0]}",
#  "c={'rect': (0, 161, 70, 46), 'size': 2363, 'labels': [9.0]}",
#  "c={'rect': (72, 171, 252, 222), 'size': 34467, 'labels': [10.0]}",
#  "c={'rect': (0, 181, 118, 85), 'size': 5270, 'labels': [11.0]}",
#  "c={'rect': (106, 210, 89, 101), 'size': 2868, 'labels': [12.0]}",
#  "c={'rect': (302, 228, 66, 96), 'size': 2531, 'labels': [13.0]}",
#  "c={'rect': (0, 253, 92, 134), 'size': 7207, 'labels': [14.0]}",
#  "c={'rect': (153, 270, 173, 179), 'size': 10360, 'labels': [15.0]}",
#  "c={'rect': (0, 305, 47, 139), 'size': 4994, 'labels': [16.0]}",
#  "c={'rect': (104, 312, 80, 71), 'size': 3595, 'labels': [17.0]}",
#  "c={'rect': (84, 360, 91, 67), 'size': 2762, 'labels': [18.0]}",
#  "c={'rect': (0, 362, 171, 87), 'size': 7705, 'labels': [19.0]}",
#  "c={'rect': (297, 364, 77, 85), 'size': 5164, 'labels': [20.0]}",
#  "c={'rect': (0, 91, 183, 175), 'size': 12312, 'labels': [7.0, 11.0]}",
#  "c={'rect': (136, 23, 117, 176), 'size': 13256, 'labels': [4.0, 5.0]}",
#  "c={'rect': (72, 171, 254, 278), 'size': 44827, 'labels': [10.0, 15.0]}",
#  "c={'rect': (134, 17, 119, 182), 'size': 15969, 'labels': [4.0, 5.0, 3.0]}",
#  "c={'rect': (302, 97, 72, 283), 'size': 13904, 'labels': [8.0, 13.0]}",
#  "c={'rect': (121, 0, 253, 226), 'size': 25143, 'labels': [2.0, 6.0]}",
#  "c={'rect': (0, 91, 183, 175), 'size': 14675, 'labels': [7.0, 11.0, 9.0]}",
#  "c={'rect': (0, 0, 144, 167), 'size': 19937, 'labels': [0.0, 1.0]}",
#  "c={'rect': (0, 0, 253, 199), 'size': 35906, 'labels': [0.0, 1.0, 4.0, 5.0, 3.0]}",
#  "c={'rect': (0, 253, 92, 191), 'size': 12201, 'labels': [14.0, 16.0]}",
#  "c={'rect': (0, 91, 183, 353), 'size': 26876, 'labels': [14.0, 16.0, 7.0, 11.0, 9.0]}",
#  "c={'rect': (0, 171, 326, 278), 'size': 52532, 'labels': [10.0, 15.0, 19.0]}",
#  "c={'rect': (0, 97, 374, 352), 'size': 66436, 'labels': [10.0, 15.0, 19.0, 8.0, 13.0]}",
#  "c={'rect': (84, 312, 100, 115), 'size': 6357, 'labels': [17.0, 18.0]}",
#  "c={'rect': (0, 91, 184, 353), 'size': 33233, 'labels': [17.0, 18.0, 14.0, 16.0, 7.0, 11.0, 9.0]}",
#  "c={'rect': (0, 91, 195, 353), 'size': 36101, 'labels': [17.0, 18.0, 14.0, 16.0, 7.0, 11.0, 9.0, 12.0]}",
#  "c={'rect': (0, 0, 374, 444), 'size': 61244, 'labels': [17.0, 18.0, 14.0, 16.0, 7.0, 11.0, 9.0, 12.0, 2.0, 6.0]}",
#  "c={'rect': (0, 0, 374, 449), 'size': 127680, 'labels': [17.0, 18.0, 14.0, 16.0, 7.0, 11.0, 9.0, 12.0, 2.0, 6.0, 10.0, 15.0, 19.0, 8.0, 13.0]}",
#  "c={'rect': (0, 0, 374, 449), 'size': 132844, 'labels': [17.0, 18.0, 14.0, 16.0, 7.0, 11.0, 9.0, 12.0, 2.0, 6.0, 10.0, 15.0, 19.0, 8.0, 13.0, 20.0]}",
#  "c={'rect': (0, 0, 374, 449), 'size': 168750, 'labels': [17.0, 18.0, 14.0, 16.0, 7.0, 11.0, 9.0, 12.0, 2.0, 6.0, 10.0, 15.0, 19.0, 8.0, 13.0, 20.0, 0.0, 1.0, 4.0, 5.0, 3.0]}"]

# %%
[cand['rect'] for cand in regions ]
# Out:
# [(0, 0, 107, 167),
#  (15, 0, 129, 110),
#  (121, 0, 253, 133),
#  (134, 17, 73, 62),
#  (166, 23, 87, 176),
#  (136, 53, 88, 121),
#  (232, 79, 117, 147),
#  (50, 91, 133, 123),
#  (305, 97, 69, 283),
#  (0, 161, 70, 46),
#  (72, 171, 252, 222),
#  (0, 181, 118, 85),
#  (106, 210, 89, 101),
#  (302, 228, 66, 96),
#  (0, 253, 92, 134),
#  (153, 270, 173, 179),
#  (0, 305, 47, 139),
#  (104, 312, 80, 71),
#  (84, 360, 91, 67),
#  (0, 362, 171, 87),
#  (297, 364, 77, 85),
#  (0, 91, 183, 175),
#  (136, 23, 117, 176),
#  (72, 171, 254, 278),
#  (134, 17, 119, 182),
#  (302, 97, 72, 283),
#  (121, 0, 253, 226),
#  (0, 91, 183, 175),
#  (0, 0, 144, 167),
#  (0, 0, 253, 199),
#  (0, 253, 92, 191),
#  (0, 91, 183, 353),
#  (0, 171, 326, 278),
#  (0, 97, 374, 352),
#  (84, 312, 100, 115),
#  (0, 91, 184, 353),
#  (0, 91, 195, 353),
#  (0, 0, 374, 444),
#  (0, 0, 374, 449),
#  (0, 0, 374, 449),
#  (0, 0, 374, 449)]

# %%
cand_rects = [cand['rect'] for cand in regions]

# %%
cand_rects
# Out:
# [(0, 0, 107, 167),
#  (15, 0, 129, 110),
#  (121, 0, 253, 133),
#  (134, 17, 73, 62),
#  (166, 23, 87, 176),
#  (136, 53, 88, 121),
#  (232, 79, 117, 147),
#  (50, 91, 133, 123),
#  (305, 97, 69, 283),
#  (0, 161, 70, 46),
#  (72, 171, 252, 222),
#  (0, 181, 118, 85),
#  (106, 210, 89, 101),
#  (302, 228, 66, 96),
#  (0, 253, 92, 134),
#  (153, 270, 173, 179),
#  (0, 305, 47, 139),
#  (104, 312, 80, 71),
#  (84, 360, 91, 67),
#  (0, 362, 171, 87),
#  (297, 364, 77, 85),
#  (0, 91, 183, 175),
#  (136, 23, 117, 176),
#  (72, 171, 254, 278),
#  (134, 17, 119, 182),
#  (302, 97, 72, 283),
#  (121, 0, 253, 226),
#  (0, 91, 183, 175),
#  (0, 0, 144, 167),
#  (0, 0, 253, 199),
#  (0, 253, 92, 191),
#  (0, 91, 183, 353),
#  (0, 171, 326, 278),
#  (0, 97, 374, 352),
#  (84, 312, 100, 115),
#  (0, 91, 184, 353),
#  (0, 91, 195, 353),
#  (0, 0, 374, 444),
#  (0, 0, 374, 449),
#  (0, 0, 374, 449),
#  (0, 0, 374, 449)]

# %%
green_rgb = (0, 255, 0)

# %%
img_rgb_copy = img_rgb.copy()

# %%
for rect in cand_rects:
    left = rect[0]
    top = rect[1]
    right = left + rect[2]
    bottom = top + rect[3]

    img_rgb_copy = cv2.rectangle(img_rgb_copy, (left, top), (right, bottom), color=green_rgb, thickness=2)

# %% [raw]
# plt.figure(figsize=(8, 8))

# %%
plt.imshow(img_rgb_copy)

# %%
cand_rects = [cand['rect'] for cand in regions if cand['size'] > 10000]

# %%
cand_rects
# Out:
# [(0, 0, 107, 167),
#  (121, 0, 253, 133),
#  (305, 97, 69, 283),
#  (72, 171, 252, 222),
#  (153, 270, 173, 179),
#  (0, 91, 183, 175),
#  (136, 23, 117, 176),
#  (72, 171, 254, 278),
#  (134, 17, 119, 182),
#  (302, 97, 72, 283),
#  (121, 0, 253, 226),
#  (0, 91, 183, 175),
#  (0, 0, 144, 167),
#  (0, 0, 253, 199),
#  (0, 253, 92, 191),
#  (0, 91, 183, 353),
#  (0, 171, 326, 278),
#  (0, 97, 374, 352),
#  (0, 91, 184, 353),
#  (0, 91, 195, 353),
#  (0, 0, 374, 444),
#  (0, 0, 374, 449),
#  (0, 0, 374, 449),
#  (0, 0, 374, 449)]

# %%
green_rgb = (0, 255, 0)
img_rgb_copy = img_rgb.copy()
for rect in cand_rects:
    left = rect[0]
    top = rect[1]
    right = left + rect[2]
    bottom = top + rect[3]

    img_rgb_copy = cv2.rectangle(img_rgb_copy, (left, top), (right, bottom), color=green_rgb, thickness=2)
plt.figure(figsize=(8, 8))
plt.imshow(img_rgb_copy)
